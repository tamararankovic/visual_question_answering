# %%
import re
import json
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %%
import nltk
from nltk.corpus import wordnet

# %%
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package wordnet to /home/tamara/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/tamara/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# image
# question
# answers
# answer_type
# answerable

# 5614  slika/pitanja
# 56140 odgovora (za svaku sliku 10 odgovora)
# 10822 jedinstvenih odgovora
#  2327 odgovora u slucaju da prihvatamo odgovor ako su barem 2/10 dali takav

# %%
in_file = read_data('train')
answers, q_answers = answer_consensus(in_file)

df = adapt_dataset(q_answers)
df.to_csv('data/train_answers.csv', index=False)

print(len(answers))
# Out:
# 2327

# %%
def read_data(dataset):
    f = open('data/' + dataset + '.json', encoding='utf8')
    data = json.load(f)
    f.close()
    return data

# %% [markdown]
# ## Pretprocesiranje odgovora

# %%
def preprocess_text(text):
    # 1) pretvaranje svih unicode karaktera u ascii (outliers)
    text = unicode_to_ascii(text)
    # 2) izbacivanje belina
    text = remove_blanks(text)
    # 3) izbacivanje specijalnih karaktera
    text = remove_special_characters(text)
    # 4) svodjenje na sva mala slova
    text = to_lower(text)
    return text

def unicode_to_ascii(text):
    return text.encode('ascii', 'ignore').decode('ascii')

def remove_blanks(text):
    without_blanks = text.replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('\\', ' ')
    without_extra_whitespace = re.sub(r'\s+', ' ', without_blanks)
    without_extra_whitespace = without_extra_whitespace.strip()
    return without_extra_whitespace

def remove_special_characters(text):
    return re.sub('[^A-Za-z0-9 ]+', '', text)

def remove_non_numeric(text):
    return re.sub('[^0-9]', '', text)

def to_lower(text):
    return text.lower()

# not very useful
def pos_tag_helper(word):
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %% [markdown]
# ## Kreiranje skupa potencijalnih odgovora

# %%
def answer_consensus(data):
    q_answers = {}
    sure_answers = {'unanswerable'}
    for key, value in data['answers'].items():
        answers = value
        # samo one za koje se moze dati odgovor
        if (data['answerable'][key]):
            # svodjenje na samo sigurne odgovore
            confident_answers = [item['answer'] for item in answers if item['answer_confidence'] != 'no']
            
            # pretprocesiranje odgovora
            processed_answers = [preprocess_text(ans) for ans in confident_answers]
            
            # za pitanja koja imaju odgovor broj, dodatno svodimo odgovore samo na broj
            if (data['answer_type'][key] == 'number'):
                processed_answers = [remove_non_numeric(ans) for ans in processed_answers if remove_non_numeric(ans)!='']
            
            # najcesci odgovor koji ima barem 2 pojavljivanja (potvrdjeni)
            counts = Counter(processed_answers)
            most_common = [k for (k, v) in counts.items() if v>=2]
            
            # ako nijedan odgovor nisu dale barem dve osobe -> unanswerable
            if most_common:
                q_answers[key] = most_common
                sure_answers.update(most_common)
            else:
                q_answers[key] = ['unanswerable']
        else:
            # odgovor je samo 'unanswerable'
            q_answers[key] = ['unanswerable']
    return sure_answers, q_answers

# %% [markdown]
# ## Pitanje-odgovor CSV

# %%
# Question, Answer1, Answer2,..., AnswerN
# uzmi sva pitanja i sve odgovore, napravi tabelu, ako se poklapa, stavi jedinicu
def adapt_dataset(q_answers):
    mlb = MultiLabelBinarizer()
    # fit_transform prima listu listi ili listu setova (za svaki key njegovu listu odgovora)
    # binarno popunjava sve odgovore u zavisnosti da li se nalaze u listi za pitanje ili ne
    mlb_result = mlb.fit_transform(list(q_answers.values()))
    # list(mlb.classes_)
    id_series = pd.Series(q_answers.keys())
    df_final = pd.concat([id_series, pd.DataFrame(mlb_result, columns=list(mlb.classes_))], axis=1)
    return df_final

# %%
list(q_answers.values())
# Out:
# [['rug', 'unanswerable'],
#  ['legs', 'shoes'],
#  ['coin'],
#  ['toilet paper'],
#  ['black', 'grey'],
#  ['purple', 'pink', 'black pink'],
#  ['black'],
#  ['yellow'],
#  ['white', 'grey', 'unsuitable'],
#  ['unsuitable', 'chicken'],
#  ['oranges', 'oranges apples', 'apples oranges'],
#  ['red'],
#  ['white'],
#  ['no'],
#  ['brown black'],
#  ['white', 'grey'],
#  ['cats', 'hairless cats'],
#  ['no'],
#  ['chair'],
#  ['unanswerable'],
#  ['green'],
#  ['sunglasses'],
#  ['tv', 'ceiling fan'],
#  ['grey', 'blue', 'unanswerable'],
#  ['pomegranate'],
#  ['grey', 'unanswerable'],
#  ['white 10 feet'],
#  ['unanswerable', 'yes', 'yes daytime'],
#  ['fan'],
#  ['pepper shaker', 'pepper'],
#  ['no', 'unanswerable', 'yes'],
#  ['pictures'],
#  ['unanswerable'],
#  ['black'],
#  ['unanswerable'],
#  ['grey', 'white'],
#  ['candy', 'lindt truffle'],
#  ['no', 'unsuitable'],
#  ['unanswerable'],
#  ['pink'],
#  ['no'],
#  ['man', 'lobby'],
#  ['american eagle', 'eagle'],
#  ['hand', 'fingers'],
#  ['better', 'unanswerable'],
#  ['unanswerable', 'no'],
#  ['goblet'],
#  ['no'],
#  ['grey'],
#  ['unsuitable', 'grey', 'white'],
#  ['speakers'],
#  ['unanswerable'],
#  ['keyboard'],
#  ['donuts'],
#  ['office chair', 'chair'],
#  ['cloudy'],
#  ['rice', 'rice meat'],
#  ['phone', 'telephone'],
#  ['black'],
#  ['yes'],
#  ['no', 'unsuitable'],
#  ['cell phone'],
#  ['paper'],
#  ['painting', 'picture'],
#  ['unanswerable', 'cereal'],
#  ['foot', 'sock'],
#  ['warning'],
#  ['garlic pepper'],
#  ['phone', 'nokia cell phone', 'cell phone'],
#  ['stuffed pokemon toy', 'pokemon', 'pikachu'],
#  ['yes'],
#  ['pink floral', 'pink flowers'],
#  ['brown'],
#  ['unanswerable'],
#  ['snowy park'],
#  ['brush', 'massager'],
#  ['green necklace'],
#  ['horizontal', 'vertical'],
#  ['smiley face'],
#  ['white', 'blue', 'light blue'],
#  ['mirror', 'unanswerable'],
#  ['blue'],
#  ['can opener'],
#  ['crunchy peanut butter', 'peanut butter'],
#  ['laptop', 'laptop computer'],
#  ['unanswerable'],
#  ['1'],
#  ['catfish'],
#  ['snickers'],
#  ['pink'],
#  ['green', 'mint green'],
#  ['coke machine', 'unanswerable'],
#  ['cash register', 'calculator', 'register'],
#  ['yellow', 'brown', 'beige'],
#  ['unsuitable'],
#  ['grey', 'white', 'light blue'],
#  ['white'],
#  ['living room', 'table', 'unsuitable'],
#  ['unsuitable', 'unanswerable'],
#  ['red', 'purple'],
#  ['yes', 'no'],
#  ['unanswerable', 'watch'],
#  ['decal'],
#  ['cell phone', 'cellphone'],
#  ['pitcher'],
#  ['paper', 'envelope', 'unanswerable', 'box'],
#  ['heater', 'radiator'],
#  ['freshmint', 'unanswerable'],
#  ['pink', 'purple'],
#  ['pie', 'cherry pie'],
#  ['unsuitable', 'grey'],
#  ['shoes'],
#  ['black', 'grey'],
#  ['keys'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['creedence cold', 'creedence gold', 'unanswerable'],
#  ['computer mouse', 'mouse'],
#  ['telephone', 'phone'],
#  ['red'],
#  ['yes'],
#  ['cloudy'],
#  ['yes'],
#  ['chair'],
#  ['blue', 'white', 'green'],
#  ['ice cream', 'unsuitable'],
#  ['shout', 'detergent', 'stain remover'],
#  ['no', 'yes'],
#  ['no'],
#  ['wallet'],
#  ['grey'],
#  ['hand'],
#  ['purple'],
#  ['weeds', 'green'],
#  ['plaid', 'red white plaid'],
#  ['brown black', 'brown'],
#  ['no', 'yes'],
#  ['broccoli', 'unsuitable'],
#  ['brown'],
#  ['1'],
#  ['blue', 'grey'],
#  ['rust', 'red', 'orange'],
#  ['headphones'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['pink', 'red'],
#  ['ipad', 'tablet'],
#  ['unanswerable'],
#  ['unsuitable'],
#  ['unanswerable'],
#  ['nap'],
#  ['white tan stripes'],
#  ['maroon pink grey'],
#  ['unanswerable', 'fleece jacket'],
#  ['unanswerable', 'tan'],
#  ['black white red', 'black red white'],
#  ['briefcase'],
#  ['computer mouse', 'mouse'],
#  ['fan temp up temp down', 'fan up down'],
#  ['unanswerable'],
#  ['white'],
#  ['orange', 'lemon'],
#  ['bell'],
#  ['yes'],
#  ['cat'],
#  ['unanswerable', 'bottle'],
#  ['cell phone', 'iphone'],
#  ['baby wipes', 'baby wipe box', 'unanswerable'],
#  ['exam table'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['flowers', 'orchids'],
#  ['screen', 'room', 'unsuitable'],
#  ['yard'],
#  ['labrador retriever', 'yellow lab', 'lab'],
#  ['yellow brown', 'yellow'],
#  ['purple green', 'purple'],
#  ['brown', 'grey', 'tan', 'beige'],
#  ['remote', 'remote control'],
#  ['grey', 'black'],
#  ['yes', 'no'],
#  ['carpet', 'unsuitable'],
#  ['yes'],
#  ['outside'],
#  ['dresser', 'unsuitable'],
#  ['fan'],
#  ['french vanilla decaf', 'french vanilla'],
#  ['black'],
#  ['phone'],
#  ['maroon', 'red'],
#  ['lotion', 'skin quencher'],
#  ['black', 'grey jacket'],
#  ['black', 'purple', 'unsuitable', 'maroon'],
#  ['cds'],
#  ['apple'],
#  ['grey', 'white', 'tan'],
#  ['unanswerable'],
#  ['no', 'unanswerable'],
#  ['yes'],
#  ['table'],
#  ['keyboard'],
#  ['t rex'],
#  ['grey', 'black'],
#  ['phone', 'unsuitable'],
#  ['white fluffy'],
#  ['tablet'],
#  ['blue black', 'blue'],
#  ['pill box'],
#  ['yes'],
#  ['dog'],
#  ['binoculars'],
#  ['unanswerable'],
#  ['no'],
#  ['napkins', 'napkin holder'],
#  ['green'],
#  ['swords', 'page swords'],
#  ['flowers'],
#  ['beaver', 'unanswerable', 'squirrel'],
#  ['white', 'grey', 'tan'],
#  ['vacuum cleaner', 'vacuum'],
#  ['ceiling fan', 'fan'],
#  ['blue', 'grey', 'black'],
#  ['wooden elephants', 'elephant'],
#  ['pink', 'magenta'],
#  ['rosary cross', 'cross'],
#  ['ash tray'],
#  ['unsuitable', 'phone'],
#  ['dolls in window'],
#  ['no'],
#  ['lamp'],
#  ['white', 'black'],
#  ['unanswerable'],
#  ['dog'],
#  ['star'],
#  ['coffee', 'unsuitable'],
#  ['fan'],
#  ['pollination'],
#  ['grey'],
#  ['grey', 'green'],
#  ['red'],
#  ['unanswerable'],
#  ['dog on bed', 'dog'],
#  ['unanswerable'],
#  ['chicken nugget', 'unanswerable'],
#  ['blue shirt white button', 'blue white'],
#  ['00 310 539'],
#  ['pencil'],
#  ['blue'],
#  ['grey', 'black'],
#  ['unanswerable'],
#  ['blue'],
#  ['blue'],
#  ['camera bag'],
#  ['blue pink'],
#  ['3'],
#  ['white chocolate', 'white'],
#  ['unanswerable', 'no'],
#  ['unanswerable'],
#  ['plaid', 'red white plaid'],
#  ['green'],
#  ['white brown', 'brown white', 'unsuitable'],
#  ['grey'],
#  ['light', 'unsuitable'],
#  ['unanswerable'],
#  ['black'],
#  ['unanswerable'],
#  ['white', 'white cat'],
#  ['grey', 'blue'],
#  ['keyboard'],
#  ['yes', 'unanswerable'],
#  ['yes', 'great'],
#  ['light', 'ceiling light', 'overhead light'],
#  ['blue'],
#  ['unanswerable', 'no swing', 'no'],
#  ['blue'],
#  ['chair'],
#  ['red'],
#  ['cell phone', 'cellphone'],
#  ['yes'],
#  ['no', 'yes'],
#  ['baby doll', 'doll'],
#  ['strawberry tart', 'strawberry tart cream'],
#  ['orange juice'],
#  ['flowers', 'poinsettia', 'poinsettia plant'],
#  ['christmas tree'],
#  ['blue'],
#  ['white'],
#  ['pink', 'hot pink'],
#  ['tea', 'iced tea'],
#  ['green'],
#  ['windows', 'window'],
#  ['lantern'],
#  ['stapler'],
#  ['yes'],
#  ['yes'],
#  ['unanswerable'],
#  ['lamp'],
#  ['cat toy'],
#  ['blue', 'green'],
#  ['red black', 'black red'],
#  ['red white', 'red'],
#  ['white'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['waterslide'],
#  ['no'],
#  ['remote control'],
#  ['pink'],
#  ['white'],
#  ['blanket', 'unanswerable'],
#  ['white'],
#  ['flowers', 'sunflowers'],
#  ['unanswerable', 'flower'],
#  ['drink', 'unanswerable'],
#  ['cell phone', 'phone'],
#  ['unanswerable'],
#  ['banana'],
#  ['candle', 'kitchen counter'],
#  ['television', 'tv'],
#  ['blue', 'black white'],
#  ['sink'],
#  ['white'],
#  ['red'],
#  ['unanswerable'],
#  ['watch'],
#  ['pepsi'],
#  ['blue'],
#  ['car'],
#  ['keyboard'],
#  ['unanswerable'],
#  ['beagle'],
#  ['blue'],
#  ['soda bottle'],
#  ['stapler'],
#  ['remote', 'remote control'],
#  ['white'],
#  ['laptop'],
#  ['blue'],
#  ['unanswerable'],
#  ['yes'],
#  ['yes', 'unanswerable'],
#  ['yellow'],
#  ['blue', 'unanswerable'],
#  ['vanilla bean'],
#  ['grey', 'grey white'],
#  ['wall', 'white wall'],
#  ['unanswerable'],
#  ['grey', 'white'],
#  ['cord', 'phone cord'],
#  ['tan', 'white'],
#  ['cake'],
#  ['unanswerable', 'braille'],
#  ['lights'],
#  ['white', 'grey'],
#  ['wood', 'wall'],
#  ['unsuitable'],
#  ['yorkie'],
#  ['pen', 'ink pen'],
#  ['green orange', 'green orange lizards'],
#  ['unanswerable'],
#  ['white', 'grey', 'blonde'],
#  ['stuffed toy'],
#  ['pen'],
#  ['tetley', 'tetley 1 cup'],
#  ['unsuitable', 'white'],
#  ['black dog'],
#  ['beer orange', 'heineken orange', 'orange'],
#  ['yes'],
#  ['yes'],
#  ['unsuitable', 'mobile phone'],
#  ['grey', 'brown'],
#  ['black white', 'black', 'blue'],
#  ['keyboard'],
#  ['brown'],
#  ['remote control', 'remote'],
#  ['black'],
#  ['computer mouse', 'mouse', 'cell phone'],
#  ['unsuitable', 'white', 'grey'],
#  ['kitchen'],
#  ['dog'],
#  ['unanswerable'],
#  ['cd', 'dvd', 'unanswerable'],
#  ['cat'],
#  ['unanswerable'],
#  ['2 wands'],
#  ['unanswerable'],
#  ['chapstick', 'yes'],
#  ['red'],
#  ['no', 'unsuitable'],
#  ['unanswerable'],
#  ['green'],
#  ['foot'],
#  ['black', 'silver', 'unsuitable'],
#  ['coffee mug', 'coffee', 'coffee cup'],
#  ['red'],
#  ['blue', 'light blue'],
#  ['white'],
#  ['storm clouds'],
#  ['pepsi', 'unanswerable'],
#  ['wreath'],
#  ['fish tank', 'aquarium'],
#  ['black'],
#  ['finger puppet', 'toy'],
#  ['homer simpson', 'bart simpson'],
#  ['stovetop', 'stove'],
#  ['black'],
#  ['backyard', 'back yard'],
#  ['bottle'],
#  ['dog'],
#  ['raft'],
#  ['blue'],
#  ['unanswerable'],
#  ['yes clouds'],
#  ['diced tomatoes'],
#  ['unanswerable'],
#  ['pink', 'maroon'],
#  ['white', 'ash color'],
#  ['on'],
#  ['tv on', 'on'],
#  ['unanswerable'],
#  ['cell phone'],
#  ['teddy bear'],
#  ['blueberry peach'],
#  ['radio'],
#  ['television', 'unanswerable'],
#  ['purple', 'pink'],
#  ['remote', 'phone'],
#  ['no'],
#  ['yes white'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['wine', 'glass wine'],
#  ['grey', 'black'],
#  ['yes', 'unanswerable'],
#  ['christmas tree', 'tree'],
#  ['red', 'pink'],
#  ['yes', 'unsuitable'],
#  ['foot'],
#  ['barbie'],
#  ['black'],
#  ['cookie on napkin', 'cookie'],
#  ['unanswerable'],
#  ['purple', 'pink'],
#  ['no', 'picture dog bone'],
#  ['blue'],
#  ['unanswerable'],
#  ['purple'],
#  ['no'],
#  ['whole chestnuts', 'chestnuts'],
#  ['tangerine', 'orange'],
#  ['barbecue', 'bbq'],
#  ['unsuitable', 'lamp'],
#  ['yes'],
#  ['white green', 'green white'],
#  ['blue'],
#  ['olives'],
#  ['vans', 'unanswerable'],
#  ['boots', 'shoes'],
#  ['unsuitable', 'blue'],
#  ['fan'],
#  ['ketchup bottle', 'ketchup'],
#  ['beige', 'grey', 'khaki'],
#  ['1 dollar', 'dollar', '2 dollars'],
#  ['iphone', 'smartphone', 'phone'],
#  ['storm'],
#  ['gold', 'yellow'],
#  ['yes'],
#  ['white'],
#  ['subaru', 'unanswerable'],
#  ['unanswerable'],
#  ['black'],
#  ['unsuitable', 'unanswerable'],
#  ['capri sun', 'juice pouch'],
#  ['yes'],
#  ['soda', 'unsuitable'],
#  ['camera lens'],
#  ['apple', 'unanswerable'],
#  ['cell phone'],
#  ['orange'],
#  ['envelope', 'box'],
#  ['curtains', 'window'],
#  ['white'],
#  ['pen', 'black pen'],
#  ['unsuitable'],
#  ['coca cola', 'coke'],
#  ['cloth', 'unanswerable'],
#  ['yellow'],
#  ['outside'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['water', 'wine'],
#  ['carpet'],
#  ['cup', 'coffee cup'],
#  ['pen'],
#  ['trees', 'fence'],
#  ['unanswerable', 'no'],
#  ['blue'],
#  ['living room'],
#  ['couch'],
#  ['unanswerable'],
#  ['brown'],
#  ['hay', 'grass'],
#  ['shirt'],
#  ['clouds', 'unanswerable'],
#  ['keyboard', 'macbook air'],
#  ['towel'],
#  ['grey', 'green'],
#  ['july 08 2011', '1 08 11', 'jul 08 11'],
#  ['ipod'],
#  ['monkey doll'],
#  ['shoes'],
#  ['light blue', 'blue'],
#  ['grey', 'blue'],
#  ['blue', 'denim blue'],
#  ['dog sleeping on floor'],
#  ['purple white', 'purple'],
#  ['dr pepper'],
#  ['kitchen'],
#  ['tea', 'coffee'],
#  ['yes'],
#  ['red'],
#  ['black'],
#  ['toy rope', 'toy'],
#  ['red'],
#  ['shirt'],
#  ['no', 'no black', 'black'],
#  ['tissues', 'tissue', 'tissue box'],
#  ['waiting room'],
#  ['headphones', 'unanswerable', 'earphones'],
#  ['can', 'unanswerable'],
#  ['pumpkin filling', 'canned pumpkin'],
#  ['right side up'],
#  ['purple grey'],
#  ['grey'],
#  ['unanswerable'],
#  ['no', 'unanswerable'],
#  ['grey'],
#  ['unanswerable'],
#  ['white'],
#  ['yes'],
#  ['paper'],
#  ['keyboard'],
#  ['john denver', 'unplugged in ussr', 'john denver unplugged in ussr'],
#  ['grey'],
#  ['left pink', 'left pink right black'],
#  ['just broccoli', 'broccoli florets', 'broccoli'],
#  ['hellmans lighter than light mayonnaise'],
#  ['yes'],
#  ['pink', 'purple'],
#  ['fairy'],
#  ['yes'],
#  ['yes'],
#  ['unanswerable'],
#  ['unanswerable', 'corn'],
#  ['foot'],
#  ['cpu', 'computer', 'computer tower'],
#  ['dolls'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['cup', 'coffee mug', 'coffee'],
#  ['unanswerable'],
#  ['wine glass'],
#  ['ocarina'],
#  ['no', 'yes'],
#  ['watch'],
#  ['rug'],
#  ['tan', 'blue', 'unanswerable'],
#  ['tables chairs', 'restaurant dining area'],
#  ['tan blue', 'purple'],
#  ['logo'],
#  ['no', 'unanswerable'],
#  ['hookah'],
#  ['daisies'],
#  ['blue screen'],
#  ['cookie dough', 'pre formed cookie dough'],
#  ['rose'],
#  ['white'],
#  ['unanswerable', 'answer questions', 'answer question'],
#  ['grape'],
#  ['unanswerable'],
#  ['plug adaptor', 'plug'],
#  ['bed'],
#  ['chicken', 'ramen'],
#  ['unanswerable', 'dandruff', 'nothing'],
#  ['unanswerable'],
#  ['living room', 'fireplace'],
#  ['table'],
#  ['blue chair', 'chair'],
#  ['purple', 'purple white', 'pink'],
#  ['white'],
#  ['pens'],
#  ['yes', 'no'],
#  ['remote', 'remote control'],
#  ['unanswerable'],
#  ['pen'],
#  ['horse'],
#  ['unanswerable', 'clothing'],
#  ['yes', 'yes green grey'],
#  ['car', 'car window'],
#  ['horse', 'black horse'],
#  ['hook'],
#  ['coffee mug', 'mug'],
#  ['lighter'],
#  ['sock'],
#  ['unanswerable'],
#  ['tree'],
#  ['pink', 'white', 'unsuitable'],
#  ['white'],
#  ['white'],
#  ['table'],
#  ['eggs in water', 'eggs'],
#  ['crown'],
#  ['iphone', 'phone'],
#  ['pink', 'pink white', 'purple white'],
#  ['grey'],
#  ['blues sliders'],
#  ['brown', 'pink', 'red'],
#  ['black'],
#  ['black white', 'white black spots'],
#  ['unanswerable', 'tan'],
#  ['roast beef', 'traditional roast beef'],
#  ['wii remote'],
#  ['yes', 'no'],
#  ['yard'],
#  ['tv', 'yamaha'],
#  ['beer', 'glass', 'beverage'],
#  ['black', 'burgundy', 'unsuitable'],
#  ['watch'],
#  ['coffee'],
#  ['light blue'],
#  ['painting'],
#  ['malibu heat', 'unanswerable'],
#  ['clear'],
#  ['pink white', 'pink'],
#  ['white', 'green'],
#  ['mug', 'coffee cup', 'cup'],
#  ['shadow', 'nothing'],
#  ['phone', 'cell phone', 'iphone'],
#  ['computer', 'unanswerable'],
#  ['sweet peas'],
#  ['unanswerable', 'cherry'],
#  ['leaf'],
#  ['phone'],
#  ['mountain dew voltage', 'mountain dew'],
#  ['grey'],
#  ['unanswerable', 'grey'],
#  ['yes'],
#  ['black brown'],
#  ['head', 'statue'],
#  ['black'],
#  ['cranberry juice', 'cranberry'],
#  ['yes'],
#  ['red'],
#  ['grey'],
#  ['mrs dash'],
#  ['couch', 'sofa'],
#  ['dog', 'puppy'],
#  ['leopard print', 'animal print', 'cheetah'],
#  ['disney'],
#  ['unsuitable', 'white'],
#  ['stovetop', 'kitchen', 'stove'],
#  ['mouse', 'computer mouse'],
#  ['spongebob clock', 'alarm clock', 'clock'],
#  ['steering wheel'],
#  ['unanswerable'],
#  ['mutual'],
#  ['unanswerable'],
#  ['black', 'blue'],
#  ['no'],
#  ['charger'],
#  ['ornament', 'christmas tree ornament'],
#  ['grey'],
#  ['unanswerable', 'dog toy'],
#  ['20'],
#  ['remote', 'remote control'],
#  ['bathroom scale', 'scale'],
#  ['no'],
#  ['blue white'],
#  ['no'],
#  ['cigarette', 'lit cigarette'],
#  ['black white', 'black white stripe'],
#  ['white'],
#  ['caramel', 'werthers', 'werthers originals'],
#  ['black', 'blue'],
#  ['dog'],
#  ['coin'],
#  ['couch', 'unanswerable'],
#  ['unanswerable', 'button'],
#  ['telephone cord'],
#  ['bronze', 'gold'],
#  ['enercell', 'unanswerable', 'unsuitable'],
#  ['blue'],
#  ['white', 'silver'],
#  ['computer'],
#  ['pink'],
#  ['grey'],
#  ['tv', 'cable box'],
#  ['tv remote', 'remote control', 'remote'],
#  ['cup', 'blue cup'],
#  ['nut'],
#  ['television', 'man'],
#  ['blue'],
#  ['brown'],
#  ['on', 'off'],
#  ['jif', 'creamy', 'jif creamy'],
#  ['black'],
#  ['yogurt'],
#  ['unanswerable'],
#  ['no'],
#  ['black white', 'yellow black'],
#  ['bananas', 'table'],
#  ['plaid'],
#  ['mound'],
#  ['pink'],
#  ['security camera', 'unanswerable'],
#  ['white', 'green purple'],
#  ['blue white'],
#  ['slinky'],
#  ['blue'],
#  ['white'],
#  ['yellow'],
#  ['grass'],
#  ['black white'],
#  ['blue sky', 'sky', 'blue'],
#  ['vanity'],
#  ['white blue green', 'blue', 'blue white green'],
#  ['80'],
#  ['peach', 'orange', 'rose pink', 'pink'],
#  ['yes', 'no'],
#  ['unanswerable', 'no'],
#  ['unanswerable'],
#  ['chair'],
#  ['motor scooter', 'scooter', 'pink scooter'],
#  ['gatorade'],
#  ['dog'],
#  ['white', 'tan', 'yellow'],
#  ['cat on couch', 'cat'],
#  ['red', 'brown'],
#  ['unanswerable', 'city'],
#  ['black'],
#  ['pen'],
#  ['black white', 'brown', 'brown white'],
#  ['white', 'green'],
#  ['pink'],
#  ['unanswerable', 'ear drops', 'no'],
#  ['4'],
#  ['stripes'],
#  ['blue', 'grey'],
#  ['yellow'],
#  ['envelope', 'numbers'],
#  ['remote control', 'remote', 'tv remote'],
#  ['car radio', 'car stereo'],
#  ['no'],
#  ['computer', 'computer screen'],
#  ['dog'],
#  ['floor', 'unanswerable'],
#  ['brown yes'],
#  ['dogs', 'black dog', 'dog'],
#  ['unanswerable'],
#  ['red', 'pink'],
#  ['white'],
#  ['ketchup'],
#  ['floor'],
#  ['unanswerable', 'power button'],
#  ['black', 'grey'],
#  ['brown'],
#  ['red', 'pink'],
#  ['room', 'floor', 'bedroom', 'carpet'],
#  ['food', 'fiber 1'],
#  ['cartoon'],
#  ['coca cola', 'coca cola coca cola'],
#  ['white'],
#  ['blue', 'nothing'],
#  ['unanswerable', 'mouse', 'computer mouse'],
#  ['purple'],
#  ['blue'],
#  ['spider'],
#  ['mcdonalds', 'mcdonalds food', 'chicken nuggets', 'happy meal'],
#  ['grey'],
#  ['no'],
#  ['plant'],
#  ['silver'],
#  ['unanswerable'],
#  ['ground beef', 'beef'],
#  ['meat lasagna', 'family meat lasagna 4 cheese blend', 'lasagna'],
#  ['unsuitable', 'blue'],
#  ['no', 'unanswerable'],
#  ['no', 'unanswerable'],
#  ['boxer briefs', 'mens underwear', 'underwear', 'briefs'],
#  ['unanswerable', 'no'],
#  ['unanswerable'],
#  ['beer', 'beer bottles'],
#  ['unsuitable', 'grey'],
#  ['red', 'unsuitable'],
#  ['relish'],
#  ['blanket'],
#  ['unsuitable', 'stuffed animal'],
#  ['kitchen sink', 'sink'],
#  ['grey', 'tan', 'beige'],
#  ['106', '105'],
#  ['yellow'],
#  ['unsuitable', 'moon'],
#  ['clock baskets', '2 baskets clock', 'clock 2 baskets'],
#  ['body lotion', 'lotion'],
#  ['shoe'],
#  ['grey', 'unanswerable'],
#  ['black green white'],
#  ['yes'],
#  ['remote', 'remote control'],
#  ['purse'],
#  ['desk'],
#  ['black'],
#  ['door', 'phone', 'telephone'],
#  ['no', 'unanswerable'],
#  ['iphone', 'cell phone'],
#  ['green'],
#  ['454'],
#  ['food'],
#  ['chair', 'waiting room'],
#  ['grey'],
#  ['brown'],
#  ['unanswerable'],
#  ['yes', 'yes grey shirt'],
#  ['white', 'grey'],
#  ['unsuitable', 'yes'],
#  ['yes'],
#  ['yes'],
#  ['khaki', 'grey'],
#  ['brown', 'black', 'black brown'],
#  ['keyboard'],
#  ['carrots'],
#  ['stairs'],
#  ['grey'],
#  ['jamaican jerk sauce', 'jerk sauce', 'jamaican jerk sauce original'],
#  ['green', 'grey'],
#  ['floor'],
#  ['pen'],
#  ['tissues', 'kleenex', 'tissue box'],
#  ['pink', 'red'],
#  ['foot'],
#  ['lollipop', 'sucker'],
#  ['tan', 'grey', 'beige'],
#  ['yes'],
#  ['green'],
#  ['unanswerable'],
#  ['tablet', 'ipad'],
#  ['unanswerable'],
#  ['easter', 'easter bunny'],
#  ['vise', 'unanswerable', 'vice'],
#  ['green', 'teal'],
#  ['unanswerable', 'pants'],
#  ['white', 'pink'],
#  ['yes'],
#  ['basketball'],
#  ['silver yes', 'grey yes'],
#  ['white', 'unsuitable', 'beige', 'yellow'],
#  ['blue white'],
#  ['golden retriever'],
#  ['purple', 'maroon'],
#  ['unanswerable'],
#  ['tye dye', 'tie dye'],
#  ['orange', 'red'],
#  ['inside', 'unanswerable'],
#  ['yes'],
#  ['unanswerable', 'no'],
#  ['legs'],
#  ['mp player', 'ipod'],
#  ['no'],
#  ['unanswerable'],
#  ['green', 'white'],
#  ['heater', 'space heater'],
#  ['unsuitable', 'laptop'],
#  ['watch', 'wrist watch'],
#  ['legs'],
#  ['talking timer'],
#  ['red'],
#  ['ultrasound', 'hair', 'unsuitable'],
#  ['unanswerable'],
#  ['organic agave nectar', 'not salad dressing'],
#  ['brown', 'unsuitable'],
#  ['no'],
#  ['living room', 'home'],
#  ['phone', 'smartphone'],
#  ['15', '14', '16'],
#  ['rain', 'no', 'storm'],
#  ['box', 'folder'],
#  ['yes', 'unanswerable'],
#  ['unanswerable'],
#  ['tropical punch'],
#  ['unanswerable'],
#  ['caterpillar', 'centipede'],
#  ['unanswerable'],
#  ['brown'],
#  ['half'],
#  ['to left'],
#  ['ear bud', 'earbud'],
#  ['unanswerable'],
#  ['pink', 'red'],
#  ['family crest', 'unanswerable'],
#  ['plant', 'unanswerable'],
#  ['static'],
#  ['pink'],
#  ['keyboard', 'computer keyboard'],
#  ['white', 'white yellow'],
#  ['yes'],
#  ['pink'],
#  ['pen'],
#  ['cheesecake', 'cake', 'pie'],
#  ['towel'],
#  ['no'],
#  ['blue'],
#  ['shakespeare'],
#  ['bird cage', 'bird in cage'],
#  ['hot pink', 'pink'],
#  ['laptop', 'unsuitable'],
#  ['unsuitable'],
#  ['tablet', 'ipad screen', 'ipad'],
#  ['unanswerable', 'food', 'unsuitable'],
#  ['charger'],
#  ['red', 'maroon'],
#  ['unanswerable'],
#  ['brown', 'tan'],
#  ['unsuitable', 'unanswerable'],
#  ['white'],
#  ['unanswerable'],
#  ['pink blue'],
#  ['yes'],
#  ['unanswerable', 'orange'],
#  ['yes'],
#  ['dollar', '1 dollar bill', 'dollar bill'],
#  ['unanswerable'],
#  ['pink'],
#  ['white'],
#  ['iphone'],
#  ['bedroom', 'bed'],
#  ['computer'],
#  ['refried beans'],
#  ['white'],
#  ['unanswerable'],
#  ['yes'],
#  ['grey', 'white'],
#  ['stereo', 'unanswerable'],
#  ['unanswerable'],
#  ['blue'],
#  ['firefox logo'],
#  ['black white'],
#  ['slide to unlock', 'no'],
#  ['wood'],
#  ['keyboard'],
#  ['grey'],
#  ['black'],
#  ['car dash', 'dashboard'],
#  ['unsuitable', 'computer screen'],
#  ['brown'],
#  ['grey'],
#  ['black'],
#  ['shoe'],
#  ['black'],
#  ['crayola eraser', 'eraser', 'crayola'],
#  ['white'],
#  ['cell phone', 'phone', 'iphone'],
#  ['grey', 'black'],
#  ['no'],
#  ['table', 'medicine box'],
#  ['0', 'g', 'unanswerable'],
#  ['fork'],
#  ['toilet paper'],
#  ['white'],
#  ['chihuahua', 'unanswerable'],
#  ['lip gloss', 'lipgloss'],
#  ['white', 'grey'],
#  ['3'],
#  ['10000'],
#  ['yellow red'],
#  ['yes'],
#  ['sierra mist soda', 'sierra mist', 'soda'],
#  ['salt'],
#  ['weeds', 'green'],
#  ['blue white black', 'blue black white'],
#  ['stuffed animal', 'stuffed aligator'],
#  ['elbow'],
#  ['white'],
#  ['pomegranate'],
#  ['card reader'],
#  ['3'],
#  ['cup', 'tea cup'],
#  ['black'],
#  ['yes'],
#  ['unanswerable'],
#  ['blue'],
#  ['orange', 'brown'],
#  ['white'],
#  ['white'],
#  ['lily'],
#  ['brown'],
#  ['black', 'black white'],
#  ['baseball card bobby higginson detroit', 'baseball'],
#  ['dog', 'unsuitable'],
#  ['grey', 'brown'],
#  ['stop light', 'traffic light'],
#  ...]

# %% [markdown]
# ## Test skup

# %%
in_file = read_data('test')
answers, q_answers = answer_consensus(in_file)
list(q_answers.values())
# Out:
# [['blue yellow', 'blue yellow stripes'],
#  ['sweet corn', 'corn'],
#  ['mug', 'travel mug', 'cup'],
#  ['white'],
#  ['melatonin'],
#  ['flower'],
#  ['pink'],
#  ['laundry basket'],
#  ['vending machine', 'soda machine'],
#  ['blue'],
#  ['drink'],
#  ['apple'],
#  ['maxi pad', 'pad'],
#  ['unanswerable'],
#  ['yellow'],
#  ['cell phone', 'cellphone'],
#  ['shepherds pie'],
#  ['paper towels', 'paper towel'],
#  ['unsuitable'],
#  ['glass'],
#  ['chair'],
#  ['phone'],
#  ['chess'],
#  ['flowers', 'roses'],
#  ['on'],
#  ['blue black', 'black blue'],
#  ['white'],
#  ['table', 'remote on table', 'tv remote on table'],
#  ['yes'],
#  ['purple', 'blue'],
#  ['yes', 'no', 'unsuitable'],
#  ['unanswerable'],
#  ['clouds trees'],
#  ['water bottle', 'empty water bottle'],
#  ['fireplace'],
#  ['richard s holiday atrium'],
#  ['yes'],
#  ['remote', 'remote control'],
#  ['cat litter'],
#  ['green fabric', 'pillow'],
#  ['floor', 'dog toys'],
#  ['black', 'white'],
#  ['flowers'],
#  ['tan', 'beige'],
#  ['blue', 'black'],
#  ['house'],
#  ['brown', 'pink'],
#  ['white black stripes', 'white black'],
#  ['unanswerable'],
#  ['pink'],
#  ['pine needles'],
#  ['grey', 'black'],
#  ['brown'],
#  ['keyboard', 'computer keyboard'],
#  ['unsuitable', 'purple'],
#  ['hat', 'sweater'],
#  ['black', 'blue'],
#  ['white'],
#  ['unsuitable', 'potstickers'],
#  ['halloween'],
#  ['leaf', 'blanket leaf on'],
#  ['tv', 'unsuitable'],
#  ['spider', 'unanswerable'],
#  ['black'],
#  ['black'],
#  ['blue fish'],
#  ['blue'],
#  ['cod liver oil'],
#  ['striped', 'grey white'],
#  ['unsuitable', 'green', 'black'],
#  ['black'],
#  ['red'],
#  ['red', 'red black'],
#  ['entertainment center', 'living room'],
#  ['white grey stripes', 'grey white stripe'],
#  ['mouth guard'],
#  ['no', 'unsuitable'],
#  ['lemon head', 'candy', 'lemon heads'],
#  ['red', 'pink'],
#  ['left'],
#  ['left'],
#  ['grey'],
#  ['laptop'],
#  ['grey', 'blue'],
#  ['blue', 'blue white'],
#  ['horse', 'dog'],
#  ['red'],
#  ['tv'],
#  ['television'],
#  ['purse', 'bag'],
#  ['progresso soup', 'soup'],
#  ['gold', 'tan'],
#  ['black', 'grey'],
#  ['drum', 'djembe'],
#  ['silver'],
#  ['grey'],
#  ['green'],
#  ['sorcerers stone', 'unanswerable'],
#  ['stove top', 'stove'],
#  ['blue', 'black'],
#  ['dog in bed', 'dog'],
#  ['brown', 'tan'],
#  ['flower'],
#  ['white'],
#  ['dog'],
#  ['phone', 'cell phone'],
#  ['calico'],
#  ['cup', 'coffee cup'],
#  ['keyboard'],
#  ['rug'],
#  ['pasta sides stroganoff', 'stroganoff'],
#  ['unanswerable'],
#  ['yes'],
#  ['green'],
#  ['shoe', 'brown shoe'],
#  ['door'],
#  ['unanswerable'],
#  ['yes', 'no', 'unanswerable'],
#  ['keyboard', 'dell computer keyboard'],
#  ['light', 'moon'],
#  ['red'],
#  ['grave stones'],
#  ['no', 'unsuitable'],
#  ['cap', 'hat'],
#  ['pen'],
#  ['5', '4'],
#  ['terrier', 'schnauzer'],
#  ['ashtray'],
#  ['stereo system', 'stereo'],
#  ['5'],
#  ['lemon pepper marinade', 'lawry lemon pepper marinade'],
#  ['turnovers', 'pastry'],
#  ['unsuitable', 'green'],
#  ['grey', 'black'],
#  ['puppies', '2 puppies'],
#  ['tv'],
#  ['guitar'],
#  ['blue', 'white'],
#  ['unanswerable', 'paper'],
#  ['feet', 'unsuitable', 'knee'],
#  ['yes'],
#  ['grey', 'white'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['blue'],
#  ['dog', 'table'],
#  ['green'],
#  ['napkin', 'paper', 'unanswerable'],
#  ['apple'],
#  ['cement block', 'bricks'],
#  ['tile', 'living room'],
#  ['box cutter'],
#  ['poinsettia'],
#  ['green'],
#  ['no'],
#  ['keyboard', 'unanswerable'],
#  ['calculator'],
#  ['orange'],
#  ['black', 'grey', 'blue'],
#  ['denim', 'jeans'],
#  ['unanswerable'],
#  ['green white'],
#  ['shirt pants yes'],
#  ['unanswerable', 'no', 'nothing'],
#  ['fruit', 'basket fruit'],
#  ['grey', 'black'],
#  ['milk'],
#  ['laundry bag', 'hamper', 'laundry basket'],
#  ['mints', 'altoids'],
#  ['red'],
#  ['unsuitable'],
#  ['brown tabby'],
#  ['onions', 'pickled onions', 'unsuitable'],
#  ['stapler'],
#  ['sweetcorn', 'corn', 'sweet corn'],
#  ['casserole'],
#  ['lighthouse'],
#  ['unsuitable'],
#  ['phone', 'cell phone'],
#  ['tablet', 'unanswerable'],
#  ['flower'],
#  ['finger'],
#  ['unanswerable', 'no'],
#  ['unanswerable'],
#  ['window'],
#  ['backpack', 'bookbag'],
#  ['blue', 'light blue'],
#  ['shoes'],
#  ['grey'],
#  ['german shepherd', 'german shepard'],
#  ['red black'],
#  ['jeans'],
#  ['black', 'unsuitable'],
#  ['unanswerable', 'remote control', 'controller', 'remote'],
#  ['unanswerable'],
#  ['fan', 'unanswerable', 'ceiling fan'],
#  ['polkadots'],
#  ['coffee', 'unanswerable'],
#  ['white', 'white t shirt'],
#  ['yes'],
#  ['unanswerable'],
#  ['plaid', 'grey plaid'],
#  ['black', 'grey', 'white'],
#  ['spinning wheel'],
#  ['ipod', 'ipod shuffle'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['cookies'],
#  ['on table', 'in front you'],
#  ['grey'],
#  ['unanswerable'],
#  ['green'],
#  ['pink', 'purple'],
#  ['unanswerable', 'no'],
#  ['orange', 'yellow', 'orange grey'],
#  ['jeans'],
#  ['dog toy'],
#  ['car'],
#  ['blue', 'white'],
#  ['grey'],
#  ['no', 'unanswerable'],
#  ['phone charger', 'charger'],
#  ['coffee pot', 'french press'],
#  ['tortilla', 'cheese slice'],
#  ['unsuitable', 'keyboard'],
#  ['food', 'pasta salad', 'pasta'],
#  ['blue'],
#  ['unanswerable', 'chocolate'],
#  ['unanswerable'],
#  ['card', 'christmas card'],
#  ['poodle'],
#  ['green white', 'white green', 'green'],
#  ['unanswerable'],
#  ['squash', 'spaghetti squash'],
#  ['negative'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['blue'],
#  ['unsuitable', 'green'],
#  ['green'],
#  ['smartphone', 'iphone', 'cell phone'],
#  ['unsuitable', 'no'],
#  ['yes'],
#  ['grey'],
#  ['orange'],
#  ['white', 'green'],
#  ['on bed', 'bed'],
#  ['yellow', 'tan', 'brown'],
#  ['balls', 'ball'],
#  ['dresser', 'chest drawers', 'dresser drawers'],
#  ['cell phone', 'phone'],
#  ['bottle', 'plastic bottle', 'unsuitable'],
#  ['elevator button'],
#  ['grey', 'blue', 'dark blue'],
#  ['brown', 'tan', 'white'],
#  ['brown', 'light brown', 'blonde'],
#  ['red'],
#  ['ceiling fan'],
#  ['unanswerable'],
#  ['chap stick', 'lip balm', 'chapstick'],
#  ['tan', 'beige'],
#  ['sleeping'],
#  ['computer tower', 'unanswerable'],
#  ['pink'],
#  ['yes'],
#  ['purple'],
#  ['painting'],
#  ['beige', 'tan'],
#  ['unsuitable', 'yes white'],
#  ['unanswerable'],
#  ['tan', 'yellow'],
#  ['brown'],
#  ['frozen dinner', 'unanswerable'],
#  ['unanswerable'],
#  ['phone', 'cell phone'],
#  ['black'],
#  ['cell phone', 'cellphone'],
#  ['keyboard'],
#  ['toilet'],
#  ['doberman'],
#  ['table', 'unanswerable'],
#  ['pasta salad', 'pasta', 'food'],
#  ['statue'],
#  ['black white'],
#  ['pink'],
#  ['television', 'tv'],
#  ['white'],
#  ['blue'],
#  ['no', 'no headphones'],
#  ['grey yellow pink', 'unsuitable'],
#  ['orange yellow flowers'],
#  ['phone', 'iphone'],
#  ['grey', 'white'],
#  ['unanswerable', 'white paper'],
#  ['nintendo', 'phone'],
#  ['unsuitable', 'seasoning'],
#  ['sock', 'sweater', 'santa socks'],
#  ['woman', 'unanswerable'],
#  ['black box', 'unsuitable', '77m'],
#  ['white'],
#  ['no', 'yes'],
#  ['5'],
#  ['unanswerable', 'rug'],
#  ['laptop'],
#  ['grey'],
#  ['no'],
#  ['phone', 'samsung cell phone', 'cellphone'],
#  ['grey'],
#  ['unanswerable'],
#  ['white'],
#  ['unanswerable'],
#  ['500', '520'],
#  ['coffee maker', 'unanswerable'],
#  ['no'],
#  ['blue'],
#  ['drawing vase'],
#  ['solid'],
#  ['black yellow'],
#  ['tan', 'brown'],
#  ['red'],
#  ['desk'],
#  ['red'],
#  ['light'],
#  ['white black', 'red', 'red white black'],
#  ['water bottle'],
#  ['gold', 'tan', 'beige'],
#  ['cottage pie', 'bistro cottage pie'],
#  ['yes', 'no'],
#  ['gecko', 'unanswerable'],
#  ['grey'],
#  ['time to see us'],
#  ['no'],
#  ['lavender', 'purple', 'pink'],
#  ['match', 'clash'],
#  ['orange'],
#  ['door', 'bed door', 'bed'],
#  ['brown', 'tan'],
#  ['unanswerable'],
#  ['no', 'yes'],
#  ['floor fan', 'fan'],
#  ['unsuitable', 'legs'],
#  ['white'],
#  ['gold'],
#  ['grey'],
#  ['fishing game', 'puzzle'],
#  ['unanswerable', 'install'],
#  ['laying on floor', 'on rug', 'on floor'],
#  ['microsoft'],
#  ['yes'],
#  ['grey'],
#  ['farm'],
#  ['unanswerable', 'laptop'],
#  ['on carpet', 'unanswerable', 'on floor'],
#  ['krusteaz', 'pancakes'],
#  ['keyboard'],
#  ['grey'],
#  ['cart', 'rolling cart'],
#  ['crystal'],
#  ['tape', 'scotch tape'],
#  ['unsuitable'],
#  ['apple'],
#  ['jvc remote', 'remote control', 'remote'],
#  ['black'],
#  ['spinach', 'cilantro'],
#  ['unanswerable'],
#  ['unanswerable'],
#  ['diet coke'],
#  ['dashboard', 'car stereo'],
#  ['black silver'],
#  ['phone', 'cell phone'],
#  ['black', 'grey'],
#  ['yes'],
#  ['yes'],
#  ['yes'],
#  ['she wore yellow ribbon'],
#  ['cup', 'glass juice'],
#  ['phone', 'cell phone'],
#  ['unanswerable'],
#  ['black'],
#  ['refrigerator'],
#  ['black'],
#  ['laptop', 'keyboard'],
#  ['no'],
#  ['cell phone', 'phone'],
#  ['trashcan', 'garbage can', 'trash can'],
#  ['nutramax'],
#  ['silver gold', 'silver'],
#  ['white'],
#  ['desk', 'unsuitable'],
#  ['table'],
#  ['snap dragon'],
#  ['unsuitable', 'phone'],
#  ['flowers', 'unanswerable'],
#  ['storage room', 'room'],
#  ['pink white', 'pink'],
#  ['bag chips', 'chips'],
#  ['computer keyboard', 'keyboard'],
#  ['keyboard', 'piano'],
#  ['blackberry', 'blackberry phone'],
#  ['white'],
#  ['peach', 'light peach'],
#  ['white'],
#  ['unanswerable'],
#  ['no'],
#  ['tan', 'beige'],
#  ['unanswerable', 'no', 'yes'],
#  ['dark brown', 'black', 'brown'],
#  ['top'],
#  ['dog', 'boxer puppy'],
#  ['white matches'],
#  ['living room'],
#  ['cell phone'],
#  ['blue'],
#  ['olives'],
#  ['beige', 'yellow'],
#  ['gift card'],
#  ['unsuitable', 'no'],
#  ['white', 'grey', 'pink'],
#  ['solid purple'],
#  ['unanswerable', 'red'],
#  ['white', 'beige'],
#  ['corduroy'],
#  ['light'],
#  ['brown', 'unsuitable'],
#  ['red', 'brown'],
#  ['kitchen', 'kitchen counter'],
#  ['cloudy'],
#  ['sky'],
#  ['black', 'unanswerable', 'unsuitable'],
#  ['light blue', 'green', 'white'],
#  ['red'],
#  ['ipad'],
#  ['blue', 'black'],
#  ['no'],
#  ['unanswerable'],
#  ['rum', 'spiced rum'],
#  ['brown', 'red', 'burgundy'],
#  ['grey', 'black', 'unsuitable'],
#  ['remote', 'remote control'],
#  ['white'],
#  ['no', 'yes'],
#  ['blue white', 'blue'],
#  ['white'],
#  ['grey'],
#  ['grey', 'no'],
#  ['phone', 'telephone'],
#  ['unanswerable'],
#  ['black white', 'black'],
#  ['flowers'],
#  ['baseball stadium'],
#  ['brown', 'black'],
#  ['sky', 'unsuitable'],
#  ['grill'],
#  ['pink', 'purple'],
#  ['unanswerable', 'pink'],
#  ['cake'],
#  ['1105', '1103', 'unanswerable'],
#  ['hand'],
#  ['right side up'],
#  ['container'],
#  ['red'],
#  ['labrador'],
#  ['cellphone', 'chair', 'phone'],
#  ['yes', 'no'],
#  ['gaucho', 'steely dan gaucho', 'unanswerable'],
#  ['unanswerable'],
#  ['unanswerable', 'upside down'],
#  ['keyboard'],
#  ['blue'],
#  ['painting'],
#  ['ornament', 'pin'],
#  ['clouds', 'sky', 'unsuitable'],
#  ['beavis'],
#  ['unanswerable'],
#  ['yes white', 'white'],
#  ['iphone', 'phone', 'cell phone'],
#  ['unanswerable'],
#  ['red'],
#  ['black'],
#  ['green', 'blue'],
#  ['blue'],
#  ['grey'],
#  ['unanswerable', 'gumballs'],
#  ['bengay pain relief massage cream', 'bengay'],
#  ['natural', 'white'],
#  ['oranges'],
#  ['white'],
#  ['unanswerable', 'television', 'tv'],
#  ['grey', 'blue'],
#  ['shaver', 'mug'],
#  ['purple'],
#  ['lotion', 'vanilla bean noel lotion'],
#  ['green', 'yellow'],
#  ['unsuitable'],
#  ['remote', 'remote control', 'tv remote'],
#  ['toy'],
#  ['phone', 'cell phone'],
#  ['on sidewalk', 'sidewalk'],
#  ['black'],
#  ['red', 'orange'],
#  ['unanswerable'],
#  ['brown'],
#  ['no', 'unanswerable'],
#  ['brown', 'black'],
#  ['yellow'],
#  ['green'],
#  ['white', 'light blue'],
#  ['amplifier', 'speaker'],
#  ['wall', 'green wall'],
#  ['unsuitable', 'pink', 'white'],
#  ['unanswerable'],
#  ['unsuitable', 'unanswerable', 'blank', 'nothing'],
#  ['kippah'],
#  ['bird', 'crow'],
#  ['window', 'curtains'],
#  ['no'],
#  ['blue', 'light blue', 'grey'],
#  ['picture frames'],
#  ['coffee press', 'french press coffee maker'],
#  ['curtain', 'curtains'],
#  ['yes', 'people', 'man in room'],
#  ['black white red', 'red white blue'],
#  ['zipper', 'unanswerable'],
#  ['pink', 'brown'],
#  ['grey', 'blue'],
#  ['last supper'],
#  ['box', 'unanswerable'],
#  ['unanswerable'],
#  ['black'],
#  ['beagle'],
#  ['blue'],
#  ['no'],
#  ['quaker cinnamon spice', 'cinnamon spice'],
#  ['celery salt', 'celery'],
#  ['yes'],
#  ['unanswerable', 'musician'],
#  ['table'],
#  ['hazelnut'],
#  ['no'],
#  ['unanswerable', 'yellow'],
#  ['jewish'],
#  ['unanswerable'],
#  ['iphone', 'phone'],
#  ['popcorn', 'kettle corn'],
#  ['unanswerable'],
#  ['christmas tree'],
#  ['white', 'unanswerable'],
#  ['computer'],
#  ['table'],
#  ['pug', 'dog'],
#  ['blue'],
#  ['no', 'no headphones'],
#  ['white'],
#  ['blue', 'denim'],
#  ['dog', 'animal'],
#  ['tv', 'television'],
#  ['leaves'],
#  ['unsuitable', 'yes yes', 'yes'],
#  ['no'],
#  ['yes'],
#  ['seeds'],
#  ['building', 'unsuitable'],
#  ['green'],
#  ['blue'],
#  ['folding chair', 'chair'],
#  ['hole punch', 'tape measure'],
#  ['purple', 'red'],
#  ['pit bull', 'boston terrier', 'mixed breed', 'pitbull'],
#  ['blue', 'blue denim'],
#  ['chair'],
#  ['blue'],
#  ['hippie chips'],
#  ['window ac unit', 'air conditioner'],
#  ['keyboard'],
#  ['unanswerable'],
#  ['keyboard'],
#  ['leg foot', 'feet'],
#  ['tv', 'unanswerable'],
#  ['grey', 'white'],
#  ['no sign'],
#  ['white'],
#  ['pasta'],
#  ['grey'],
#  ['unanswerable', 'baggage claim'],
#  ['walmart', 'staples'],
#  ['flash drive', 'unanswerable'],
#  ['tomato sauce', 'sauce'],
#  ['kidney beans'],
#  ['cat'],
#  ['cat'],
#  ['food', 'salad'],
#  ['barack obama', 'barrack obama'],
#  ['jesus'],
#  ['no'],
#  ['blue', 'brown'],
#  ['plate food', 'food'],
#  ['red'],
#  ['yes'],
#  ['yes'],
#  ['white', 'unsuitable'],
#  ['yes'],
#  ['green black', 'black green'],
#  ['led magnifying glass', 'magnifier', 'magnifying glass'],
#  ['red'],
#  ['yes'],
#  ['green', 'green white'],
#  ['currency', 'money'],
#  ['yes'],
#  ['unanswerable'],
#  ['tea'],
#  ['copper', 'pink'],
#  ['black'],
#  ['yes'],
#  ['chunk light tuna', 'tuna'],
#  ['yes', 'no'],
#  ['white polka dots', 'polka dots'],
#  ['cat'],
#  ['santa'],
#  ['tan'],
#  ['keyboard'],
#  ['fox', 'firefox'],
#  ['joker']]

# %%
len(list(q_answers.values()))
# Out:
# 624

# %%
test_df = adapt_dataset(q_answers)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Columns: 433 entries, 0 to zipper
# dtypes: int64(432), object(1)
# memory usage: 2.1+ MB

# %%
test_df.rename(columns = {0: '0'}, inplace = True)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Columns: 433 entries, 0 to zipper
# dtypes: int64(432), object(1)
# memory usage: 2.1+ MB

# %%
train_df = pd.read_csv('data/train_answers.csv')
train_cols = train_df.columns
test_cols = test_df.columns
drop_columns = list(set(test_cols) - set(train_cols))
add_columns = list(set(train_cols) - set(test_cols))
print(len(drop_columns))
print(len(add_columns))
# Out:
# 197
# 2092

# %%
test_df.drop(columns=drop_columns, inplace=True)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Columns: 236 entries, 0 to zipper
# dtypes: int64(235), object(1)
# memory usage: 1.1+ MB

# %%
add_df = pd.DataFrame(columns=add_columns)
add_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Columns: 2092 entries, dessert to advanced creme rinse
# dtypes: object(2092)
# memory usage: 0.0+ bytes

# %%
test_df = test_df.join(add_df)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Columns: 2328 entries, 0 to advanced creme rinse
# dtypes: int64(235), object(2093)
# memory usage: 11.1+ MB

# %%
test_df = test_df.reindex(sorted(test_df.columns), axis=1)
test_df.head()
# Out:
#       0  0.1 00 310 539    1 1 08 11  1 3 1 4 ounce 1 cup 1 dollar  \
# 0  7824  NaN        NaN  NaN     NaN  NaN       NaN   NaN      NaN
# 1  7288  NaN        NaN  NaN     NaN  NaN       NaN   NaN      NaN
# 2  6489  NaN        NaN  NaN     NaN  NaN       NaN   NaN      NaN
# 3  9376  NaN        NaN  NaN     NaN  NaN       NaN   NaN      NaN
# 4  6591  NaN        NaN  NaN     NaN  NaN       NaN   NaN      NaN
#
#   1 dollar bill  ... yes green grey yes grey shirt yes no yes on yes white  \
# 0           NaN  ...            NaN            NaN    NaN    NaN         0
# 1           NaN  ...            NaN            NaN    NaN    NaN         0
# 2           NaN  ...            NaN            NaN    NaN    NaN         0
# 3           NaN  ...            NaN            NaN    NaN    NaN         0
# 4           NaN  ...            NaN            NaN    NaN    NaN         0
#
#   yes yes yogurt yoplait yorkie zipper
# 0       0    NaN     NaN    NaN      0
# 1       0    NaN     NaN    NaN      0
# 2       0    NaN     NaN    NaN      0
# 3       0    NaN     NaN    NaN      0
# 4       0    NaN     NaN    NaN      0
#
# [5 rows x 2328 columns]

# %%
test_df.fillna(0, inplace=True)

# %%
test_df.to_csv('data/test_answers.csv', index=False)

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

# %%
len(intersection(train_df.columns, test_df.columns))
# Out:
# 2328
